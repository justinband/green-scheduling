# %%
from importlib import reload
import mdps
import q_learning
reload(mdps.single_process)
reload(q_learning)
from q_learning import QLearn
from mdps.single_process import SingleProcessCostsMDP
import matplotlib.pyplot as plt
import numpy as np

# %%
NUM_STATES = 5
env = SingleProcessCostsMDP(NUM_STATES)
env.reset()

EPISODES = 10000
EPSILON = 0.1
GAMMA = 0.95
q_learn = QLearn(env, epsilon=EPSILON, episodes=EPISODES)
hist = q_learn.execute()
# Out:
# R: [1. 1. 1. 1. 0.]

# %%
env.r
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.],
#        [1., 1.],
#        [1., 0.]])

# %%
print("Optimal Q:", hist[-1])
print("Optimal Policy:", q_learn.optimal_policy)

q_learn.compute_loss()
q_learn.plot_loss(True, False)
# Out:
# Optimal Q: [[0.71170409 0.58287123]
#  [0.59153327 0.45501057]
#  [0.45856698 0.31338941]
#  [0.31923696 0.16839346]
#  [0.16254314 0.00112786]]
# Optimal Policy: [1 1 1 1 1]
