# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from importlib import reload
import energy_data
reload(energy_data)
from energy_data import EnergyData

energy_data = EnergyData('DK_2023_hourly.csv')

# %%
energy_data.plot_data(
    title="Distribution of Hourly Danish Carbon Intensities in 2023",
    density=True
)
# Out:
# Mean: 93.65446461187216
# SD: 57.66221289874355
# +1 SD: 151.3166775106157
# -1 SD: 35.99225171312861
# Upper Bound: 197.995

# %%
energy_data.plot_outliers()
# Out:
# ['2023-01-02T05:00:00.000000000' '2023-01-02T06:00:00.000000000'
#  '2023-01-02T07:00:00.000000000' '2023-01-02T08:00:00.000000000'
#  '2023-01-02T09:00:00.000000000' '2023-01-02T10:00:00.000000000'
#  '2023-01-02T11:00:00.000000000' '2023-01-02T12:00:00.000000000'
#  '2023-01-02T13:00:00.000000000' '2023-01-02T14:00:00.000000000'
#  '2023-01-02T15:00:00.000000000' '2023-01-02T16:00:00.000000000'
#  '2023-01-05T12:00:00.000000000' '2023-01-05T13:00:00.000000000'
#  '2023-01-05T14:00:00.000000000' '2023-01-05T16:00:00.000000000'
#  '2023-01-10T00:00:00.000000000' '2023-01-18T15:00:00.000000000'
#  '2023-01-18T17:00:00.000000000' '2023-01-19T17:00:00.000000000'
#  '2023-01-20T06:00:00.000000000' '2023-01-20T07:00:00.000000000'
#  '2023-01-20T08:00:00.000000000' '2023-01-20T09:00:00.000000000'
#  '2023-01-20T14:00:00.000000000' '2023-01-20T15:00:00.000000000'
#  '2023-01-20T16:00:00.000000000' '2023-01-20T17:00:00.000000000'
# ...

# %%
energy_data.normalized_data.mean()
# Out:
# 0.1610224826811495
